# %%
# !pip install telebot

# %%
import telebot
from telebot import types
import requests
from bs4 import BeautifulSoup

# Подключение к боту через токен
bot = telebot.TeleBot('Здесь находится токен, который мы получаем через BotFather')

# Создаём кнопки 'start' и 'main' в интерфейсе бота
# Прописываем текст для ответа пользователю
@bot.message_handler(commands=['start', 'main'])
def welcome_message(message):
    bot.send_message(message.chat.id, f'Привет, {message.from_user.first_name}!')
    bot.send_message(message.chat.id, f'Для продолжения поздоровайтесь👋')

# Создаём кнопку 'help' в интерфейсе бота и добавляем условие
# Если пользователь правильным словом поздоровался с ботом, то открываем меню
# Если пользователь неправильно поздоровался с ботом, то открываем помощь
@bot.message_handler(commands=['help'])
def help_message(message):
    bot.send_message(message.chat.id, 'Напиши <b><em>привет</em></b>', parse_mode='html')

@bot.message_handler(content_types=['text'])
def text_message(message):
    if message.text.lower() == 'привет':
        main_markup = types.InlineKeyboardMarkup(row_width=2)
        item_squeezing = types.InlineKeyboardButton(text="Отжимания", callback_data="squeezing")
        item_reverse_squeezing = types.InlineKeyboardButton(text="Обратные отжимания", callback_data="reverse_squeezing")
        item_chin_ups = types.InlineKeyboardButton(text="Подтягивания", callback_data="chin_ups")
        item_squats = types.InlineKeyboardButton(text="Приседания", callback_data="squats")
        item_twisting = types.InlineKeyboardButton(text="Скручивания", callback_data="twisting")
        item_reverse_twisting = types.InlineKeyboardButton(text="Обратные скручивания", callback_data="reverse_twisting")
        item_legs_lift = types.InlineKeyboardButton(text="Подъём ног", callback_data="legs_lift")
        item_lunges = types.InlineKeyboardButton(text="Выпады", callback_data="lunges")
        item_bridge = types.InlineKeyboardButton(text="Ягодичный мостик", callback_data="bridge")
        item_burpee = types.InlineKeyboardButton(text="Бёрпи", callback_data="burpee")
        main_markup.add(item_squeezing, item_reverse_squeezing, item_chin_ups, item_squats, item_twisting,
                   item_reverse_twisting, item_legs_lift, item_lunges, item_bridge, item_burpee)
        bot.send_message(message.chat.id,
                         'Добро пожаловать в бота, который сможет сделать тебя лучше! Для взаимодействия используй кнопочки ниже👇',
                         reply_markup=main_markup)
    else:
        bot.send_message(message.chat.id,
                         'Система тебя не понимает, отправь /help')

# Далее к каждой кнопке с упражнениями парсим информацию в виде картинки либо текста
# В этом нам помогают библиотеки BeautifulSoup и requests
# Библиотека requests позволяет нам обрабатывать запросы к сайтам
# Библиотека BeautifulSoup позволяет нам обрабатывать HTML-код
# После парсинга мы получаем картинку либо текст
@bot.callback_query_handler(func = lambda call: True)
def answer(call):
    if call.data == "squeezing":
       bot.send_message(call.message.chat.id, "Изучим отжимания")
       response_pic1 = requests.get('https://img.setka.io/g_eV3G1PVcIGegFPbtDZDJROz2HAw8kG23QjXnCl8u0/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/otzhimaniya.png')
       with open('pic1_image.jpg', 'wb') as pic1:
           pic1.write(response_pic1.content)
       with open('pic1_image.jpg', 'rb') as pic1:
        bot.send_photo(call.message.chat.id, pic1)
       response_text1 = requests.get(
           'https://ru.wikipedia.org/wiki/%D0%9E%D1%82%D0%B6%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D1%8F')
       soup_squeezing = BeautifulSoup(response_text1.text, 'html.parser')
       text1 = soup_squeezing.find('div', class_='mw-parser-output').find('p').text.strip()
       bot.send_message(call.message.chat.id, text1)
       menu_markup = types.InlineKeyboardMarkup(row_width=1)
       item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
       menu_markup.add(item_menu)
       bot.send_message(call.message.chat.id,"Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "reverse_squeezing":
        bot.send_message(call.message.chat.id, "Изучим обратные отжимания")
        response_pic2 = requests.get(
            'https://img.setka.io/VKw3BgtrsQhl-22sfaD9L3JPihZpRSiKi08ENm9MzYA/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/obratnye-otzhimaniya.png')
        with open('pic1_image.jpg', 'wb') as pic2:
            pic2.write(response_pic2.content)
        with open('pic1_image.jpg', 'rb') as pic2:
            bot.send_photo(call.message.chat.id, pic2)
        menu_markup = types.InlineKeyboardMarkup(row_width=1)
        item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
        menu_markup.add(item_menu)
        bot.send_message(call.message.chat.id, "Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "chin_ups":
        bot.send_message(call.message.chat.id, "Изучим подтягивания")
        response_pic3 = requests.get(
            'https://img.setka.io/78nWC8mXigYfs8vFvJrkc_GqzQgY1wHlZBijmO059z4/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/podtyagivaniya.png')
        with open('pic1_image.jpg', 'wb') as pic3:
            pic3.write(response_pic3.content)
        with open('pic1_image.jpg', 'rb') as pic3:
            bot.send_photo(call.message.chat.id, pic3)
        response_text2 = requests.get(
            'https://ru.wikipedia.org/wiki/%D0%9F%D0%BE%D0%B4%D1%82%D1%8F%D0%B3%D0%B8%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F')
        soup_chin_ups = BeautifulSoup(response_text2.text, 'html.parser')
        text2 = soup_chin_ups.find('div', class_='mw-parser-output').find('p').text.strip()
        bot.send_message(call.message.chat.id, text2)
        menu_markup = types.InlineKeyboardMarkup(row_width=1)
        item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
        menu_markup.add(item_menu)
        bot.send_message(call.message.chat.id, "Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "squats":
        bot.send_message(call.message.chat.id, "Изучим приседания")
        response_pic3 = requests.get(
            'https://img.setka.io/2myTLr9mtAERe4humBgIPQ1CAoppa59y23y0zJPA7WA/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/prisedaniya-2.png')
        with open('pic1_image.jpg', 'wb') as pic4:
            pic4.write(response_pic3.content)
        with open('pic1_image.jpg', 'rb') as pic4:
            bot.send_photo(call.message.chat.id, pic4)
        response_text3 = requests.get(
            'https://ru.wikipedia.org/wiki/%D0%9F%D1%80%D0%B8%D1%81%D0%B5%D0%B4%D0%B0%D0%BD%D0%B8%D1%8F')
        soup_chin_ups = BeautifulSoup(response_text3.text, 'html.parser')
        text3 = soup_chin_ups.find('div', class_='mw-parser-output').find('p').text.strip()
        bot.send_message(call.message.chat.id, text3)
        menu_markup = types.InlineKeyboardMarkup(row_width=1)
        item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
        menu_markup.add(item_menu)
        bot.send_message(call.message.chat.id, "Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "twisting":
        bot.send_message(call.message.chat.id, "Изучим скручивания")
        response_pic3 = requests.get(
            'https://img.setka.io/NGRnOH1Q_QPQYWc8F7ZvkkDEXRR4TTfvCMOJgp9XGH8/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/skruchivaniya-4.png')
        with open('pic1_image.jpg', 'wb') as pic5:
            pic5.write(response_pic3.content)
        with open('pic1_image.jpg', 'rb') as pic5:
            bot.send_photo(call.message.chat.id, pic5)
        response_text4 = requests.get(
            'https://ru.wikipedia.org/wiki/%D0%A1%D0%BA%D1%80%D1%83%D1%87%D0%B8%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F')
        soup_chin_ups = BeautifulSoup(response_text4.text, 'html.parser')
        text4 = soup_chin_ups.find('div', class_='mw-parser-output').find('p').text.strip()
        bot.send_message(call.message.chat.id, text4)
        menu_markup = types.InlineKeyboardMarkup(row_width=1)
        item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
        menu_markup.add(item_menu)
        bot.send_message(call.message.chat.id, "Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "reverse_twisting":
        bot.send_message(call.message.chat.id, "Изучим обратные скручивания")
        response_pic3 = requests.get(
            'https://img.setka.io/1EXYtPMCvbFVBOxqu3Pf-RkD7hwW2iZVM5xuyVNwQyk/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/obratnye-skruchivaniya-1.png')
        with open('pic1_image.jpg', 'wb') as pic6:
            pic6.write(response_pic3.content)
        with open('pic1_image.jpg', 'rb') as pic6:
            bot.send_photo(call.message.chat.id, pic6)
        menu_markup = types.InlineKeyboardMarkup(row_width=1)
        item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
        menu_markup.add(item_menu)
        bot.send_message(call.message.chat.id, "Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "legs_lift":
        bot.send_message(call.message.chat.id, "Изучим подъём ног")
        response_pic3 = requests.get(
            'https://img.setka.io/2xdk5p70_O75rc7b5t9Lkd6SiWyQdVVGORJ_U69-gmE/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/podem-nog-2.png')
        with open('pic1_image.jpg', 'wb') as pic7:
            pic7.write(response_pic3.content)
        with open('pic1_image.jpg', 'rb') as pic7:
            bot.send_photo(call.message.chat.id, pic7)
        menu_markup = types.InlineKeyboardMarkup(row_width=1)
        item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
        menu_markup.add(item_menu)
        bot.send_message(call.message.chat.id, "Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "lunges":
        bot.send_message(call.message.chat.id, "Изучим выпады")
        response_pic3 = requests.get(
            'https://img.setka.io/tj-psYc3Xyd_rFfcvPLLvj-X4geVYD_jP8NBGbsmrDk/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/vypady-(1).png')
        with open('pic1_image.jpg', 'wb') as pic8:
            pic8.write(response_pic3.content)
        with open('pic1_image.jpg', 'rb') as pic8:
            bot.send_photo(call.message.chat.id, pic8)
        response_text5 = requests.get('https://ru.wikipedia.org/wiki/%D0%92%D1%8B%D0%BF%D0%B0%D0%B4%D1%8B')
        soup_chin_ups = BeautifulSoup(response_text5.text, 'html.parser')
        text5 = soup_chin_ups.find('div', class_='mw-parser-output').find('p').text.strip()
        bot.send_message(call.message.chat.id, text5)
        menu_markup = types.InlineKeyboardMarkup(row_width=1)
        item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
        menu_markup.add(item_menu)
        bot.send_message(call.message.chat.id, "Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "bridge":
        bot.send_message(call.message.chat.id, "Изучим ягодичный мостик")
        response_pic3 = requests.get(
            'https://img.setka.io/T0uUPOFLVt3SBPKybmQU7paGjOnGzA0KV6BspB26-rU/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/yagodichnyi-mostik.png')
        with open('pic1_image.jpg', 'wb') as pic9:
            pic9.write(response_pic3.content)
        with open('pic1_image.jpg', 'rb') as pic9:
            bot.send_photo(call.message.chat.id, pic9)
        menu_markup = types.InlineKeyboardMarkup(row_width=1)
        item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
        menu_markup.add(item_menu)
        bot.send_message(call.message.chat.id, "Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "burpee":
        bot.send_message(call.message.chat.id, "Изучим бёрпи")
        response_pic3 = requests.get(
            'https://img.setka.io/ezHXCfxk8aj7GoYdlus7RdnHCC80UHN5sEbvC0kUF4Y/w:1000/q:88/plain/clients/ERswQaPUWaeWgjb6hekcAkZGgz6Intd3/post_images/berpi.png')
        with open('pic1_image.jpg', 'wb') as pic10:
            pic10.write(response_pic3.content)
        with open('pic1_image.jpg', 'rb') as pic10:
            bot.send_photo(call.message.chat.id, pic10)
        response_text6 = requests.get('https://ru.wikipedia.org/wiki/%D0%91%D1%91%D1%80%D0%BF%D0%B8')
        soup_chin_ups = BeautifulSoup(response_text6.text, 'html.parser')
        text6 = soup_chin_ups.find('div', class_='mw-parser-output').find('p').text.strip()
        bot.send_message(call.message.chat.id, text6)
        menu_markup = types.InlineKeyboardMarkup(row_width=1)
        item_menu = types.InlineKeyboardButton(text="Меню", callback_data="back_to_menu")
        menu_markup.add(item_menu)
        bot.send_message(call.message.chat.id, "Назад к выбору упражнения", reply_markup=menu_markup)

    elif call.data == "back_to_menu":
        main_markup = types.InlineKeyboardMarkup(row_width=2)
        item_squeezing = types.InlineKeyboardButton(text="Отжимания", callback_data="squeezing")
        item_reverse_squeezing = types.InlineKeyboardButton(text="Обратные отжимания",
                                                            callback_data="reverse_squeezing")
        item_chin_ups = types.InlineKeyboardButton(text="Подтягивания", callback_data="chin_ups")
        item_squats = types.InlineKeyboardButton(text="Приседания", callback_data="squats")
        item_twisting = types.InlineKeyboardButton(text="Скручивания", callback_data="twisting")
        item_reverse_twisting = types.InlineKeyboardButton(text="Обратные скручивания",
                                                           callback_data="reverse_twisting")
        item_legs_lift = types.InlineKeyboardButton(text="Подъём ног", callback_data="legs_lift")
        item_lunges = types.InlineKeyboardButton(text="Выпады", callback_data="lunges")
        item_bridge = types.InlineKeyboardButton(text="Ягодичный мостик", callback_data="bridge")
        item_burpee = types.InlineKeyboardButton(text="Бёрпи", callback_data="burpee")
        main_markup.add(item_squeezing, item_reverse_squeezing, item_chin_ups, item_squats, item_twisting,
                        item_reverse_twisting, item_legs_lift, item_lunges, item_bridge, item_burpee)
        bot.send_message(call.message.chat.id,
                         'Вы вернулись в главное меню! Выберете упражнение ниже👇',
                         reply_markup=main_markup)
# Запускаем бота
bot.infinity_polling()
